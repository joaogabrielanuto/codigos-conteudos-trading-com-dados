# %% [markdown]
# <a href="https://colab.research.google.com/github/joaogabrielanuto/Laboratorio-de-Codigos/blob/main/Nuvem_de_palavras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textract
# !pip install wordcloud
# !pip install nltk

# %%
import textract
from wordcloud import WordCloud, ImageColorGenerator
import nltk
import matplotlib.pyplot as plt

# %%
noticia = "/content/noticia_Brasil.pdf"

texto = textract.process(noticia).decode("utf-8")
texto
# Out:
# '17/11/2022 15:13\n\nIbovespa em queda forte, dólar chegando a bater R$ 5,53: o novo dia de forte aversão ao risco com PEC da transição e falas de Lula - InfoMoney\n\nRisco fiscal no radar\nIbovespa em queda forte, dólar chegando a bater R$ 5,53: o\nnovo dia de forte aversão ao risco com PEC da transição e falas\nde Lula\nInvestidores repercutem hoje a proposta em PEC de tirar do teto R$ 175 bilhões para Bolsa Família, mas\nexpectativa é de texto mais enxuto do Congresso\n\nPor Equipe InfoMoney\n17 nov 2022 10h46-Atualizado 3 horas atrás\n\n\uf09a \uf099 \uf3fe \uf232 \uf08c \uf0e0\n\nFalas de Lula desde a eleição já derrubaram Ibov e\nFalas de Lula desde a eleição já derrubaram Ibov e……\n\nO risco fiscal segue no radar dos investidores em Brasil, que repercutem\nnesta quinta-feira (17) a apresentação na noite de ontem do anteprojeto para\na PEC da transição, além de novas falas do presidente eleito Luiz Inácio Lula\nda Silva.  Na véspera, o Ibovespa fechou em queda de 2,58%, a 110.2
# ...

# %%
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('portuguese')
#stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords.append('R')

# %%
nuvem_palavras = WordCloud(stopwords=stopwords,
                      background_color="black",
                      width=1200, height=800).generate(texto)

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax.set_axis_off()
plt.imshow(wordcloud);

# %%
wordcloud.to_file("nuvem_palavras.png")

# %%
nuvem_palavras = WordCloud(stopwords=stopwords,
                      background_color="yellow", max_words=20, contour_width=1,
                      repeat=False,
                      width=1200, height=800).generate(texto)

fig, ax = plt.subplots(figsize=(16,9))
ax.set_axis_off()
plt.imshow(nuvem_palavras);
