# %% [markdown]
# <a href="https://colab.research.google.com/github/joaogabrielanuto/codigos-conteudos-trading-com-dados/blob/main/aleatorio_pt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import numpy as np

# %%
qtde_elementos = 2000

# %%
lista_numeros = []

for i in range (0,(qtde_elementos)):
    lista_numeros.append(random.choice([-1,1]))

df_lista_numeros = pd.DataFrame(lista_numeros,
                                columns=['numero'])

# %%
df_lista_numeros['soma'] = df_lista_numeros['numero'].cumsum()

# %%
df_lista_numeros['media_20'] = df_lista_numeros['soma'].rolling(20).mean()
df_lista_numeros['media_200'] = df_lista_numeros['soma'].rolling(200).mean()

# %%
df_lista_numeros.plot(figsize=(12,9),
                      y=['soma', 'media_20', 'media_200']);
